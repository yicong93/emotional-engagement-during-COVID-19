# %%
from textblob import TextBlob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import nltk

# %%
otd = pd.read_csv("Pathos_data_April30.csv", index_col = 0)
otd = spark.createDataFrame(otd)

# %%
otd.dtypes
# Out:
# [('Date', 'string'),
#  ('Time', 'string'),
#  ('Company Name', 'string'),
#  ('Current Feelings', 'string'),
#  ('Future Expectations', 'string'),
#  ('Need Now', 'string'),
#  ('City', 'string'),
#  ('Expect_recovery', 'string'),
#  ('Change_In_Life', 'string')]

# %%
# shape of data
print((otd.count(), len(otd.columns)))
# Out:
# (302, 9)

# %%
from pyspark.sql.functions import isnan, when, count, col
# check null values
otd.select([count(when(isnan(c), c)).alias(c) for c in otd.columns]).show()
# Out:
# +----+----+------------+----------------+-------------------+--------+----+---------------+--------------+
# |Date|Time|Company Name|Current Feelings|Future Expectations|Need Now|City|Expect_recovery|Change_In_Life|
# +----+----+------------+----------------+-------------------+--------+----+---------------+--------------+
# |   0|   0|           0|               0|                  0|       0|   0|              0|             0|
# +----+----+------------+----------------+-------------------+--------+----+---------------+--------------+

# %% [markdown]
# Changing the Datetime data type

# %%
#otd['Datetime'] = pd.to_datetime(otd['Date'] + ' ' +  otd['Time'])
import pyspark.sql.functions as F
split_col = F.split(otd['Date'], '-')
otd = otd.withColumn('Day', split_col.getItem(0))
otd = otd.withColumn('Month', split_col.getItem(1))
otd = otd.withColumn('Year', split_col.getItem(2))

otd=otd.withColumn("Date", F.to_date(F.concat_ws("-", "Year", "Month", "Day")) )
col_reorder = ['Date', 'Company Name', 'Current Feelings', 'Future Expectations', 'Need Now',
              'City', 'Expect_recovery','Change_In_Life']
otd = otd[col_reorder]

# %%
otd.show()
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# |      Date|        Company Name|    Current Feelings| Future Expectations|            Need Now|        City| Expect_recovery|Change_In_Life|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# |2020-04-15|  baseH technologies|i am feeling not ...|hopefully all thi...|    the world to run|     karachi|        3 months|     No Change|
# |2020-04-15|              Amazim|            Not good|          Don't know|              Relief|       Delhi|        6 months|     No Change|
# |2020-04-15|            Citibank|I feel rarely tha...|                 Bad|             Freedom|      Austin|          1 year|     No Change|
# |2020-04-15|   Noshn Advertising|       uncomfortable|wont be the same ...|               Money|      Kuwait|          1 year|     No Change|
# |2020-04-15|       self business|            anxious.|          optimistic|  financial security| mississauga|         1 month|     No Change|
# |2020-04-15|       self business|             anxious|            positive|  financial security| mississauga|More than a year|     No Change|
# |2020-04-15|                citi|                okay|                 yes|                  no|         pak|More than a year|     No Change|
# |2020-04-15|              Google|         not so good|               bleak|that I would not ...|      Austin|         1 month|     No Change|
# |2020-04-15|Self employed but...|Nervous anxious a...| Not very optimistic|Money having a jo...|    Winnipeg|          1 year|     No Change|
# |2020-04-15|             Company|           Concerned|          Optimistic|People suffering ...|  New Jersey|          1 year|     No Change|
# |2020-04-15|       Self employed|                 Sad|More challenging ...|             Economy|      Manama|         1 month|     No Change|
# |2020-04-15|             Textile|           Uncertain|          Optimistic|The economy will ...|      Jaipur|         1 month|     No Change|
# |2020-04-15|At a consulting firm|           Uncertain|Eventually we wil...|The economy will ...|     Chicago|         1 month|     No Change|
# |2020-04-15| Independent advisor|uneasy, like I'm ...|          Optimistic|The health of my ...|Westport, CT|        6 months|     No Change|
# |2020-04-15|          Technology|                Dull|             Worried|             Economy|   Bangalore|         1 month|     No Change|
# |2020-04-15|        I don't work|       In acceptance|  Things will change|Wondering how lon...|       Cairo|         1 month|     No Change|
# |2020-04-15|Manager of a pres...|      Mixed emotions|I think things wi...|My biggest concer...|        Doha|More than a year|     No Change|
# |2020-04-15|        Intelligenes|         Not so good|Will be different...|Kids education, c...|  Burlington|        6 months|     No Change|
# |2020-04-15|          Innovation|             Curious|Lots of opportuni...|    When it will end|    Montreal|          1 year|     No Change|
# |2020-04-15|        intelligenes|                 sad|              gloomy|               money|     karachi|         1 month|     No Change|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### Nature Language Process

# %%
# *** Import pakages for NLP ***
from pyspark.ml.feature import CountVectorizer,StringIndexer, RegexTokenizer,StopWordsRemover
from pyspark.sql.functions import col, udf,regexp_replace,isnull
from pyspark.sql.types import StringType,IntegerType
#pip install wordcloud
from wordcloud import WordCloud
import nltk
import os

# %%
# sotd = spark.read.csv('Pathos_data_April30.csv', header = 'True', inferSchema ='True')
sotd = otd

# %%
#sotd = spark.createDataFrame(otd)
sotd.columns
# Out:
# ['Date',
#  'Company Name',
#  'Current Feelings',
#  'Future Expectations',
#  'Need Now',
#  'City',
#  'Expect_recovery',
#  'Change_In_Life']

# %%
sotd.show()
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# |      Date|        Company Name|    Current Feelings| Future Expectations|            Need Now|        City| Expect_recovery|Change_In_Life|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# |2020-04-15|  baseH technologies|i am feeling not ...|hopefully all thi...|    the world to run|     karachi|        3 months|     No Change|
# |2020-04-15|              Amazim|            Not good|          Don't know|              Relief|       Delhi|        6 months|     No Change|
# |2020-04-15|            Citibank|I feel rarely tha...|                 Bad|             Freedom|      Austin|          1 year|     No Change|
# |2020-04-15|   Noshn Advertising|       uncomfortable|wont be the same ...|               Money|      Kuwait|          1 year|     No Change|
# |2020-04-15|       self business|            anxious.|          optimistic|  financial security| mississauga|         1 month|     No Change|
# |2020-04-15|       self business|             anxious|            positive|  financial security| mississauga|More than a year|     No Change|
# |2020-04-15|                citi|                okay|                 yes|                  no|         pak|More than a year|     No Change|
# |2020-04-15|              Google|         not so good|               bleak|that I would not ...|      Austin|         1 month|     No Change|
# |2020-04-15|Self employed but...|Nervous anxious a...| Not very optimistic|Money having a jo...|    Winnipeg|          1 year|     No Change|
# |2020-04-15|             Company|           Concerned|          Optimistic|People suffering ...|  New Jersey|          1 year|     No Change|
# |2020-04-15|       Self employed|                 Sad|More challenging ...|             Economy|      Manama|         1 month|     No Change|
# |2020-04-15|             Textile|           Uncertain|          Optimistic|The economy will ...|      Jaipur|         1 month|     No Change|
# |2020-04-15|At a consulting firm|           Uncertain|Eventually we wil...|The economy will ...|     Chicago|         1 month|     No Change|
# |2020-04-15| Independent advisor|uneasy, like I'm ...|          Optimistic|The health of my ...|Westport, CT|        6 months|     No Change|
# |2020-04-15|          Technology|                Dull|             Worried|             Economy|   Bangalore|         1 month|     No Change|
# |2020-04-15|        I don't work|       In acceptance|  Things will change|Wondering how lon...|       Cairo|         1 month|     No Change|
# |2020-04-15|Manager of a pres...|      Mixed emotions|I think things wi...|My biggest concer...|        Doha|More than a year|     No Change|
# |2020-04-15|        Intelligenes|         Not so good|Will be different...|Kids education, c...|  Burlington|        6 months|     No Change|
# |2020-04-15|          Innovation|             Curious|Lots of opportuni...|    When it will end|    Montreal|          1 year|     No Change|
# |2020-04-15|        intelligenes|                 sad|              gloomy|               money|     karachi|         1 month|     No Change|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+
# only showing top 20 rows

# %% [markdown]
# Stemming

# %%
from pyspark.sql.functions import monotonically_increasing_id

sotd_to_stem = sotd["Current Feelings","Future Expectations","Need Now"]
cols_for_stem = ["Current Feelings","Future Expectations","Need Now"]
df_stem = []
for colu in cols_for_stem:
    col_name = str (colu + "_Stem")
    regex_tokenizer = RegexTokenizer(inputCol = colu, outputCol= col_name, pattern="\\W")
    raw_words = regex_tokenizer.transform(sotd_to_stem.select(colu))
    df_stem.append(raw_words)
    
    
df_1 = df_stem[0].withColumn("id", monotonically_increasing_id())
df_2 = df_stem[1].withColumn("id", monotonically_increasing_id())
df_3 = df_stem[2].withColumn("id", monotonically_increasing_id())
df_complete = df_1.join(df_2, "id","outer").join(df_3, "id", "outer").drop("id")


df_complete = df_complete.select(col("Current Feelings_Stem").alias("curr_stem"),
                                 col("Future Expectations_Stem").alias("future_stem"),
                                 col("Need Now_Stem").alias("now_stem"))

df_complete.show()
# Out:
# +--------------------+--------------------+--------------------+
# |           curr_stem|         future_stem|            now_stem|
# +--------------------+--------------------+--------------------+
# | [sad, and, anxious]|[the, future, wil...|[economic, impact...|
# |        [reflective]|[it, is, going, t...|[elderly, in, fam...|
# |[manageable, if, ...|[good, everyone, ...|[i, am, essential...|
# |[anxiety, but, co...|[future, will, be...|[safety, and, wel...|
# |           [anxious]|[i, foresee, grea...|[when, will, we, ...|
# |           [anxious]|[generally, posit...|[health, and, fin...|
# |      [apprehensive]|[optimistic, but,...|[finances, econom...|
# |         [energized]|          [positive]|         [schooling]|
# |[i, am, ok, worki...|[a, new, world, w...|[not, much, deliv...|
# |               [sad]|            [gloomy]|             [money]|
# |           [anxious]|[a, more, closed,...|[how, long, this,...|
# | [worried, and, sad]|        [optimistic]|[suffering, from,...|
# |[i, am, feeling, ...|[hopefully, all, ...|[the, world, to, ...|
# |[depressed, faile...|[bleak, dead, end...|[my, work, place,...|
# |   [a, bit, anxious]|   [it, looks, grim]|[job, security, m...|
# |              [shit]|             [blank]|        [everything]|
# |[connected, but, ...|[it, s, going, to...|[how, do, i, go, ...|
# |          [insecure]|         [uncertain]|[job, guarantee, ...|
# |[the, same, as, u...|[very, positive, ...|[financial, well,...|
# |[energized, and, ...|[cautiosly, optmi...|   [losing, my, job]|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
def lemma(x):
    nltk.download('wordnet')
    from nltk.stem import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    return lemmatizer.lemmatize(x)



from nltk.corpus import stopwords
StopWords = stopwords.words('english')
add_stop=["people","one"]
StopWords=StopWords+add_stop

col_to_wiz = ['curr_stem', 'future_stem','now_stem']
df_lst =[]
for column in col_to_wiz:
    curr = df_complete.rdd.map(lambda x: x[column]).filter(lambda x: x is not None)
    token = curr\
             .map(lambda word: [x for x in word if x.isalpha()])\
             .map(lambda word: [x for x in word if len(x) >= 3])\
             .map(lambda word: [x for x in word if x not in StopWords])\
             .map(lambda word: [lemma(x) for x in word])\
             .map(lambda word: [str(TextBlob(x).correct()) for x in word])
    temp = spark.createDataFrame([[l] for l in token.collect()], [column])
    df_lst.append(temp)

# %%
#from pyspark.sql.functions import monotonically_increasing_id
df_1 = df_lst[0].withColumn("id", monotonically_increasing_id())
df_2 = df_lst[1].withColumn("id", monotonically_increasing_id())
df_3 = df_lst[2].withColumn("id", monotonically_increasing_id())
new_complete = df_1.join(df_2, "id","outer").join(df_3, "id", "outer").drop("id")
new_complete.show()
# Out:
# +--------------------+--------------------+--------------------+
# |           curr_stem|         future_stem|            now_stem|
# +--------------------+--------------------+--------------------+
# |              [good]|             [bleak]|[would, able, sur...|
# |[effective, grate...|[optimism, believ...|[work, housing, i...|
# |            [scared]|  [going, difficult]|               [end]|
# |               [bad]|               [bad]|          [isolated]|
# |[current, situati...|[live, everyday, ...|[pakistani, gover...|
# |               [bad]|[think, improving...|     [job, security]|
# |[slightly, depres...|[bleak, bleak, wo...|[workwise, hard, ...|
# |         [miserable]|[ink, supply, sit...|  [going, run, food]|
# |           [blessed]|[believe, everyth...|[die, without, ac...|
# |[energies, anxiou...|[cautiously, opti...|       [losing, job]|
# |[exhausted, irrit...|[nothing, coming,...|         [get, home]|
# |[bit, boring, tim...|[hopefully, rebound]|[global, health, ...|
# |      [sad, anxious]|[future, altered,...|[economic, impact...|
# |               [sad]|              [sure]|  [going, end, soon]|
# |    [mixed, emotion]|[think, thing, ge...|[biggest, concern...|
# |    [calm, grateful]|           [hopeful]|[everyone, food, ...|
# |               [bad]|             [risky]|      [people, life]|
# |[concerned, yet, ...|[full, opportunit...|[health, well, co...|
# |   [scar, uncertain]|[take, time, reco...|       [job, health]|
# |        [frustrated]|[thing, get, bett...|           [economy]|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Word Frequency

# %%
def wordCount(word):
    return (word.groupBy('corrected').count())

def correct_text (word):
    if len(word) > 2:
        return str(TextBlob(word).correct())
    else:
        return None

correct_udf = udf(correct_text)

# %%
from pyspark.sql.functions import split, explode, col
## Current Feeling Corpus:
new_complete.select(new_complete.columns[0]).collect()
curr_word = new_complete.select(col("curr_stem"))
curr_word = curr_word.select(explode(curr_word.curr_stem).alias('word'))
curr_word = curr_word.withColumn('corrected', correct_udf('word')).dropna()

curr_word_freq = wordCount(curr_word).orderBy('count', ascending = False)
curr_word_freq.show()
# Out:
# +-----------+-----+
# |  corrected|count|
# +-----------+-----+
# |    anxious|   41|
# |  uncertain|   22|
# |        sad|   20|
# |  concerned|   17|
# |        bad|   15|
# |       good|   14|
# |    worried|   13|
# |        bit|   12|
# |    feeling|   12|
# |     little|   11|
# |       time|   10|
# |     future|   10|
# |       feel|    9|
# |   stressed|    7|
# |      bored|    7|
# |     really|    6|
# |        end|    6|
# |uncertainty|    6|
# |opportunity|    6|
# |       like|    6|
# +-----------+-----+
# only showing top 20 rows

# %%
# Future expr Corpus
future_word = new_complete.select(col("future_stem"))
future_word = future_word.select(explode(future_word.future_stem).alias('word'))
future_word = future_word.withColumn('corrected', correct_udf('word')).dropna()

future_word_freq = wordCount(future_word).orderBy('count', ascending = False)
future_word_freq.show()
# Out:
# +----------+-----+
# | corrected|count|
# +----------+-----+
# |  positive|   23|
# |      time|   22|
# |    future|   20|
# |optimistic|   20|
# | uncertain|   18|
# |     going|   18|
# |       get|   18|
# |    better|   17|
# |     thing|   16|
# |    normal|   14|
# |    change|   11|
# |      back|   10|
# |     world|   10|
# |       new|   10|
# |      hope|   10|
# |      sure|   10|
# |     bleak|   10|
# |      take|    9|
# |      term|    9|
# | different|    8|
# +----------+-----+
# only showing top 20 rows

# %%
# Need Now Corpus:
now_word = new_complete.select(col("now_stem"))
now_word = now_word.select(explode(now_word.now_stem).alias('word'))
now_word = now_word.withColumn('corrected', correct_udf('word')).dropna()

now_word_freq = wordCount(now_word).orderBy('count', ascending = False)
now_word_freq.show()
# Out:
# +-----------+-----+
# |  corrected|count|
# +-----------+-----+
# |     health|   42|
# |        job|   38|
# |     family|   28|
# |   security|   26|
# |  financial|   18|
# |     safety|   17|
# |    economy|   16|
# |   economic|   15|
# |       life|   13|
# |   business|   13|
# |       work|   12|
# |        end|   11|
# |      money|   10|
# |    concern|   10|
# |uncertainty|   10|
# |       food|   10|
# |        one|    9|
# |     impact|    9|
# |     normal|    9|
# |       long|    8|
# +-----------+-----+
# only showing top 20 rows

# %%
# Draw the histogram for Word Frequency in each documents

import seaborn as sns


pd_curr_word_freq = curr_word_freq.toPandas().sort_values('count', ascending = False).head(5)
pd_future_word_freq = future_word_freq.toPandas().sort_values('count', ascending = False).head(5)
pd_now_word_freq = now_word_freq.toPandas().sort_values('count', ascending = False).head(5)

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (12,8))
wc_df_lst = [pd_curr_word_freq, pd_future_word_freq,pd_now_word_freq]

txt_lst = sotd["Current Feelings","Future Expectations","Need Now"]
i = 0


for txt in txt_lst:
    plt.subplot(1,3,i+1)
    sns.barplot(y="corrected", x="count",data=wc_df_lst[i])
    sns.set(rc = {'figure.figsize': (8,6)})
    plt.xlabel("Count")
    plt.title("Word Frequency for %s" %txt_lst[i])
    display()
    i += 1

plt.tight_layout()
#plt.subplots_adjust(wspace =3, hspace =3)

# %%
# Draw the Word Clouds
import matplotlib.pyplot as plt
import wordcloud
from wordcloud import WordCloud
from PIL import Image
import numpy as np
import urllib
import requests

shelter_mask = np.array(Image.open(requests.get('http://www.clker.com/cliparts/O/i/x/Y/q/P/yellow-house-hi.png', stream=True).raw))

pd_curr_word_freq = curr_word_freq.toPandas()
pd_future_word_freq = future_word_freq.toPandas()
pd_now_word_freq = now_word_freq.toPandas()
dfs = [pd_curr_word_freq, pd_future_word_freq,pd_now_word_freq]

title_lst = ['Current Feeling', 'Future Expectation', 'Need Now']
i =0

for curr_df in dfs:
    wc_df = curr_df.set_index('corrected').T.to_dict('records')
    
    wordcloud_cur = WordCloud(width=500, 
                          height=500, 
                          random_state=30, 
                          max_font_size=100, 
                          relative_scaling=0.5, 
                          colormap='Dark2', 
                          background_color = 'white', 
                          mask = shelter_mask).generate_from_frequencies(dict(*wc_df))
    plt.figure(figsize=(14, 10),facecolor = 'white', edgecolor='blue')    
    plt.title("Word Cloud for %s" %title_lst[i],fontsize=20)
    plt.imshow(wordcloud_cur) #interpolation="bilinear")
    plt.axis('off')
    plt.show()
    display()
    i += 1

# %% [markdown]
# ### Scoring Emotions

# %%
# pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *

def udf_po(text):
    score = analyzer.polarity_scores(text)
    for (k,v) in score.items():
            if k == 'compound':
                return v

# NOTE: it seems that calls to udf() must be after SparkContext() is called
udfValueToPo = udf(udf_po, FloatType())

# %%
otd = otd.withColumn("Current Feelings com_score", udfValueToPo("Current Feelings"))
otd = otd.withColumn("Future Exp com_score", udfValueToPo("Future Expectations"))

# %%
otd=otd.withColumnRenamed('Company Name','Com_name')
otd=otd.withColumnRenamed('Current Feelings','Curr_feels')
otd=otd.withColumnRenamed('Future Expectations','Future_exp')
otd=otd.withColumnRenamed('Need Now','Need_now')
otd=otd.withColumnRenamed('Current Feelings com_score','Curr_score')
otd=otd.withColumnRenamed('Future Exp com_score','Future_score')

# %%
otd.createOrReplaceTempView('otd')

# %%
# Find out the number of records in diff days
from pyspark.sql.functions import month, dayofmonth

Num_of_record = otd.groupBy(month('Date'), dayofmonth('Date')).count().orderBy('month(Date)','dayofmonth(Date)')
Num_of_record.show()
# Out:
# +-----------+----------------+-----+
# |month(Date)|dayofmonth(Date)|count|
# +-----------+----------------+-----+
# |          4|              15|   86|
# |          4|              16|    9|
# |          4|              19|    2|
# |          4|              20|    6|
# |          4|              21|   27|
# |          4|              22|   25|
# |          4|              23|   31|
# |          4|              24|   31|
# |          4|              25|   21|
# |          4|              26|   35|
# |          4|              27|   14|
# |          4|              28|    5|
# |          4|              29|    3|
# |          4|              30|    6|
# |          5|               1|    1|
# +-----------+----------------+-----+

# %%
sotd_with_label = spark.sql("""
select substring(a.Date,6,5) as date, a.label, count(*) as cnts
from
(SELECT Date , CASE WHEN (Curr_score < 0 AND Future_score > 0.5) THEN "with_big_hope"
                WHEN (Curr_score < 0 AND Future_score between 0 and 0.5) THEN "with_little_hope"
                WHEN (Curr_score < 0 AND Future_score < 0) THEN "pessimisitcs"
                WHEN (Curr_score >= 0 AND Future_score >= 0) THEN "optimistics"
                WHEN (Curr_score >= 0 AND Future_score < 0) THEN "holpless"
                ELSE "neutral"
                END AS Label
                FROM otd) a
group by substring(a.Date,6,5),a.label
order by substring(a.Date,6,5),a.label
""")
sotd_with_label.show()
# Out:
# +-----+----------------+----+
# | date|           label|cnts|
# +-----+----------------+----+
# |04-15|        holpless|   7|
# |04-15|     optimistics|  17|
# |04-15|    pessimisitcs|  17|
# |04-15|   with_big_hope|  11|
# |04-15|with_little_hope|  34|
# |04-16|     optimistics|   3|
# |04-16|    pessimisitcs|   6|
# |04-19|    pessimisitcs|   2|
# |04-20|        holpless|   1|
# |04-20|    pessimisitcs|   1|
# |04-20|with_little_hope|   4|
# |04-21|        holpless|   4|
# |04-21|     optimistics|   6|
# |04-21|    pessimisitcs|   6|
# |04-21|   with_big_hope|   4|
# |04-21|with_little_hope|   7|
# |04-22|        holpless|   3|
# |04-22|     optimistics|   5|
# |04-22|    pessimisitcs|   7|
# |04-22|   with_big_hope|   4|
# +-----+----------------+----+
# only showing top 20 rows

# %%
sotd_with_label.createOrReplaceTempView('table_label')
sotd_with_label_percent=spark.sql("""
select a.date,a.label,round(a.cnts/a.totals,2) as percent
from
(select *,sum(cnts) over(partition by date) as totals
from table_label) a
order by a.date,a.label
""")
sotd_with_label_percent.show()
# Out:
# +-----+----------------+-------+
# | date|           label|percent|
# +-----+----------------+-------+
# |04-15|        holpless|   0.08|
# |04-15|     optimistics|    0.2|
# |04-15|    pessimisitcs|    0.2|
# |04-15|   with_big_hope|   0.13|
# |04-15|with_little_hope|    0.4|
# |04-16|     optimistics|   0.33|
# |04-16|    pessimisitcs|   0.67|
# |04-19|    pessimisitcs|    1.0|
# |04-20|        holpless|   0.17|
# |04-20|    pessimisitcs|   0.17|
# |04-20|with_little_hope|   0.67|
# |04-21|        holpless|   0.15|
# |04-21|     optimistics|   0.22|
# |04-21|    pessimisitcs|   0.22|
# |04-21|   with_big_hope|   0.15|
# |04-21|with_little_hope|   0.26|
# |04-22|        holpless|   0.12|
# |04-22|     optimistics|    0.2|
# |04-22|    pessimisitcs|   0.28|
# |04-22|   with_big_hope|   0.16|
# +-----+----------------+-------+
# only showing top 20 rows

# %%
from datetime import datetime
sotd_with_label_percent = sotd_with_label_percent.toPandas()
sotd_with_label_percent['date'] =  pd.to_datetime(sotd_with_label_percent['date'], format='%m-%d')
fig, ax = plt.subplots(figsize=(16, 6))
a=sns.lineplot(data=sotd_with_label_percent, x='date', y='percent', hue='label')

# %%
sotd_with_label1 = spark.sql("""
SELECT * , CASE WHEN (Curr_score < 0 AND Future_score > 0.5) THEN "with_big_hope"
                WHEN (Curr_score < 0 AND Future_score between 0 and 0.5) THEN "with_little_hope"
                WHEN (Curr_score < 0 AND Future_score < 0) THEN "pessimisitcs"
                WHEN (Curr_score >= 0 AND Future_score >= 0) THEN "optimistics"
                WHEN (Curr_score >= 0 AND Future_score < 0) THEN "holpless"
                ELSE "neutral"
                END AS Label
                FROM otd
""")
sotd_with_label1.show()
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+
# |      Date|            Com_name|          Curr_feels|          Future_exp|            Need_now|        City| Expect_recovery|Change_In_Life|Curr_score|Future_score|           Label|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+
# |2020-04-15|  baseH technologies|i am feeling not ...|hopefully all thi...|    the world to run|     karachi|        3 months|     No Change|   -0.2278|      0.6808|   with_big_hope|
# |2020-04-15|              Amazim|            Not good|          Don't know|              Relief|       Delhi|        6 months|     No Change|   -0.3412|         0.0|with_little_hope|
# |2020-04-15|            Citibank|I feel rarely tha...|                 Bad|             Freedom|      Austin|          1 year|     No Change|     0.431|     -0.5423|        holpless|
# |2020-04-15|   Noshn Advertising|       uncomfortable|wont be the same ...|               Money|      Kuwait|          1 year|     No Change|   -0.3818|         0.0|with_little_hope|
# |2020-04-15|       self business|            anxious.|          optimistic|  financial security| mississauga|         1 month|     No Change|     -0.25|      0.3182|with_little_hope|
# |2020-04-15|       self business|             anxious|            positive|  financial security| mississauga|More than a year|     No Change|     -0.25|      0.5574|   with_big_hope|
# |2020-04-15|                citi|                okay|                 yes|                  no|         pak|More than a year|     No Change|    0.2263|      0.4019|     optimistics|
# |2020-04-15|              Google|         not so good|               bleak|that I would not ...|      Austin|         1 month|     No Change|   -0.3865|         0.0|with_little_hope|
# |2020-04-15|Self employed but...|Nervous anxious a...| Not very optimistic|Money having a jo...|    Winnipeg|          1 year|     No Change|   -0.7351|     -0.2912|    pessimisitcs|
# |2020-04-15|             Company|           Concerned|          Optimistic|People suffering ...|  New Jersey|          1 year|     No Change|       0.0|      0.3182|     optimistics|
# |2020-04-15|       Self employed|                 Sad|More challenging ...|             Economy|      Manama|         1 month|     No Change|   -0.4767|      0.2247|with_little_hope|
# |2020-04-15|             Textile|           Uncertain|          Optimistic|The economy will ...|      Jaipur|         1 month|     No Change|    -0.296|      0.3182|with_little_hope|
# |2020-04-15|At a consulting firm|           Uncertain|Eventually we wil...|The economy will ...|     Chicago|         1 month|     No Change|    -0.296|      0.8047|   with_big_hope|
# |2020-04-15| Independent advisor|uneasy, like I'm ...|          Optimistic|The health of my ...|Westport, CT|        6 months|     No Change|   -0.3182|      0.3182|with_little_hope|
# |2020-04-15|          Technology|                Dull|             Worried|             Economy|   Bangalore|         1 month|     No Change|   -0.4019|      -0.296|    pessimisitcs|
# |2020-04-15|        I don't work|       In acceptance|  Things will change|Wondering how lon...|       Cairo|         1 month|     No Change|    0.4588|         0.0|     optimistics|
# |2020-04-15|Manager of a pres...|      Mixed emotions|I think things wi...|My biggest concer...|        Doha|More than a year|     No Change|       0.0|      0.4404|     optimistics|
# |2020-04-15|        Intelligenes|         Not so good|Will be different...|Kids education, c...|  Burlington|        6 months|     No Change|   -0.3865|         0.0|with_little_hope|
# |2020-04-15|          Innovation|             Curious|Lots of opportuni...|    When it will end|    Montreal|          1 year|     No Change|    0.3182|      0.3818|     optimistics|
# |2020-04-15|        intelligenes|                 sad|              gloomy|               money|     karachi|         1 month|     No Change|   -0.4767|     -0.1531|    pessimisitcs|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+
# only showing top 20 rows

# %%
## Alignning the Unit of Time 
#otd_w_label = sotd_with_label1.toPandas()
sotd_with_label1.createOrReplaceTempView('otd_w_label')

otd_w_labels = spark.sql("""
SELECT *, CASE WHEN (Expect_recovery = '3 months') or (Expect_recovery = 'Three months at least') THEN '3 Months'
                WHEN Expect_recovery = '1 month' THEN '1 Month'
                WHEN Expect_recovery = '6 months' THEN 'Half Year'
                WHEN Expect_recovery in ('1 year','A year') THEN 'A Year'
                WHEN Expect_recovery = 'More than a year' THEN 'More Than A Year'
                WHEN Expect_recovery = 'too many months' THEN 'Uncertain Time'
                END AS Recovery_time_label
FROM otd_w_label
""")
display(otd_w_labels.show())
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+-------------------+
# |      Date|            Com_name|          Curr_feels|          Future_exp|            Need_now|        City| Expect_recovery|Change_In_Life|Curr_score|Future_score|           Label|Recovery_time_label|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+-------------------+
# |2020-04-15|  baseH technologies|i am feeling not ...|hopefully all thi...|    the world to run|     karachi|        3 months|     No Change|   -0.2278|      0.6808|   with_big_hope|           3 Months|
# |2020-04-15|              Amazim|            Not good|          Don't know|              Relief|       Delhi|        6 months|     No Change|   -0.3412|         0.0|with_little_hope|          Half Year|
# |2020-04-15|            Citibank|I feel rarely tha...|                 Bad|             Freedom|      Austin|          1 year|     No Change|     0.431|     -0.5423|        holpless|             A Year|
# |2020-04-15|   Noshn Advertising|       uncomfortable|wont be the same ...|               Money|      Kuwait|          1 year|     No Change|   -0.3818|         0.0|with_little_hope|             A Year|
# |2020-04-15|       self business|            anxious.|          optimistic|  financial security| mississauga|         1 month|     No Change|     -0.25|      0.3182|with_little_hope|            1 Month|
# |2020-04-15|       self business|             anxious|            positive|  financial security| mississauga|More than a year|     No Change|     -0.25|      0.5574|   with_big_hope|   More Than A Year|
# |2020-04-15|                citi|                okay|                 yes|                  no|         pak|More than a year|     No Change|    0.2263|      0.4019|     optimistics|   More Than A Year|
# |2020-04-15|              Google|         not so good|               bleak|that I would not ...|      Austin|         1 month|     No Change|   -0.3865|         0.0|with_little_hope|            1 Month|
# |2020-04-15|Self employed but...|Nervous anxious a...| Not very optimistic|Money having a jo...|    Winnipeg|          1 year|     No Change|   -0.7351|     -0.2912|    pessimisitcs|             A Year|
# |2020-04-15|             Company|           Concerned|          Optimistic|People suffering ...|  New Jersey|          1 year|     No Change|       0.0|      0.3182|     optimistics|             A Year|
# |2020-04-15|       Self employed|                 Sad|More challenging ...|             Economy|      Manama|         1 month|     No Change|   -0.4767|      0.2247|with_little_hope|            1 Month|
# |2020-04-15|             Textile|           Uncertain|          Optimistic|The economy will ...|      Jaipur|         1 month|     No Change|    -0.296|      0.3182|with_little_hope|            1 Month|
# |2020-04-15|At a consulting firm|           Uncertain|Eventually we wil...|The economy will ...|     Chicago|         1 month|     No Change|    -0.296|      0.8047|   with_big_hope|            1 Month|
# |2020-04-15| Independent advisor|uneasy, like I'm ...|          Optimistic|The health of my ...|Westport, CT|        6 months|     No Change|   -0.3182|      0.3182|with_little_hope|          Half Year|
# |2020-04-15|          Technology|                Dull|             Worried|             Economy|   Bangalore|         1 month|     No Change|   -0.4019|      -0.296|    pessimisitcs|            1 Month|
# |2020-04-15|        I don't work|       In acceptance|  Things will change|Wondering how lon...|       Cairo|         1 month|     No Change|    0.4588|         0.0|     optimistics|            1 Month|
# |2020-04-15|Manager of a pres...|      Mixed emotions|I think things wi...|My biggest concer...|        Doha|More than a year|     No Change|       0.0|      0.4404|     optimistics|   More Than A Year|
# |2020-04-15|        Intelligenes|         Not so good|Will be different...|Kids education, c...|  Burlington|        6 months|     No Change|   -0.3865|         0.0|with_little_hope|          Half Year|
# |2020-04-15|          Innovation|             Curious|Lots of opportuni...|    When it will end|    Montreal|          1 year|     No Change|    0.3182|      0.3818|     optimistics|             A Year|
# |2020-04-15|        intelligenes|                 sad|              gloomy|               money|     karachi|         1 month|     No Change|   -0.4767|     -0.1531|    pessimisitcs|            1 Month|
# +----------+--------------------+--------------------+--------------------+--------------------+------------+----------------+--------------+----------+------------+----------------+-------------------+
# only showing top 20 rows
# None

# %%
otd_w_labels.toPandas().to_csv('Downloads/pathos_with_labels.csv', index = False)
otd_w_labels.toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 12 columns):
# Date                   302 non-null object
# Com_name               302 non-null object
# Curr_feels             302 non-null object
# Future_exp             302 non-null object
# Need_now               302 non-null object
# City                   302 non-null object
# Expect_recovery        302 non-null object
# Change_In_Life         302 non-null object
# Curr_score             302 non-null float32
# Future_score           302 non-null float32
# Label                  302 non-null object
# Recovery_time_label    302 non-null object
# dtypes: float32(2), object(10)
# memory usage: 26.0+ KB

# %% [markdown]
# ### LDA Model

# %%
otd_rdd = otd.rdd

# %%
otd_rdd
# Out:
# MapPartitionsRDD[420] at javaToPython at NativeMethodAccessorImpl.java:0

# %%
#from nltk.corpus import stopwords
import re
from pyspark.ml.feature import CountVectorizer, IDF
#nltk.download('stopwords')


# stuffs we will need for building the model
from pyspark.mllib.linalg import Vector, Vectors
from pyspark.mllib.clustering import LDA, LDAModel


#StopWords = stopwords.words('english')
need_now = df_lst[2].rdd.map(lambda x: x['now_stem'])
token = need_now.zipWithIndex()

# %%
token.collect()
# Out:
# [(['economic', 'impact', 'could'], 0),
#  (['elderly', 'family'], 1),
#  (['essential',
#    'service',
#    'worker',
#    'hoping',
#    'continue',
#    'support',
#    'frontline',
#    'stay',
#    'healthy',
#    'burn'],
#   2),
#  (['safety', 'well', 'family'], 3),
#  (['free', 'corona'], 4),
#  (['health', 'financial', 'security'], 5),
#  (['finance', 'economy', 'career'], 6),
#  (['choosing'], 7),
#  (['much', 'delivering', 'work', 'time', 'despite', 'challenge'], 8),
#  (['money'], 9),
#  (['long', 'last', 'life', 'normal'], 10),
#  (['suffering', 'virus', 'economic', 'crisis'], 11),
#  (['world', 'run'], 12),
#  (['work', 'place', 'current', 'situation', 'cause', 'corona'], 13),
#  (['job', 'security', 'managing', 'home', 'traveling'], 14),
#  (['everything'], 15),
#  (['achieve', 'want'], 16),
#  (['job', 'guarantee', 'alive'], 17),
#  (['financial', 'well', 'safety', 'others'], 18),
#  (['losing', 'job'], 19),
#  (['long', 'term', 'job', 'position', 'financial', 'sustainability'], 20),
#  (['keep', 'family', 'isolation'], 21),
#  (['future', 'economy'], 22),
#  (['coming', 'strategy', 'armada', 'right'], 23),
#  (['personally',
#    'worried',
#    'situation',
#    'fine',
#    'son',
#    'young',
#    'lose',
#    'job',
#    'get',
#    'sick'],
#   24),
#  (['tedious', 'try', 'suck', 'brain'], 25),
#  (['would', 'able', 'survive'], 26),
#  (['getting', 'job'], 27),
#  (['risk', 'transparent', 'elderly', 'relative', 'becoming', 'ill'], 28),
#  (['work',
#    'housing',
#    'industry',
#    'worried',
#    'liquidity',
#    'worried',
#    'homeless',
#    'afford',
#    'rent',
#    'worry',
#    'systems',
#    'breaking',
#    'offer',
#    'support',
#    'need'],
#   29),
#  (['older', 'brother', 'nursing', 'home', 'sitting', 'asthma'], 30),
#  (['long', 'going', 'take', 'world', 'normal', 'cost'], 31),
#  (['staying', 'safe', 'meeting', 'end'], 32),
#  (['normally'], 33),
#  (['nothing'], 34),
#  (['economy'], 35),
#  (['elderly', 'parent', 'time', 'take', 'get', 'back', 'new', 'normal'], 36),
#  (['food'], 37),
#  (['food'], 38),
#  (['job', 'security'], 39),
#  (['job',
#    'insecurity',
#    'distress',
#    'lack',
#    'routine',
#    'missing',
#    'seeing',
#    'friend',
#    'social',
#    'interaction'],
#   40),
#  (['business', 'growth'], 41),
#  (['job', 'security'], 42),
#  (['economy', 'collapse'], 43),
#  (['health', 'everyone', 'food', 'needy'], 44),
#  (['safe'], 45),
#  (['uncertainty', 'future'], 46),
#  (['job', 'security'], 47),
#  (['mother', 'health'], 48),
#  (['illness', 'financial', 'clarity'], 49),
#  ([], 50),
#  (['getting', 'helper', 'clean', 'house'], 51),
#  (['catching', 'virus', 'vulnerable', 'category'], 52),
#  (['illness'], 53),
#  (['get', 'home'], 54),
#  (['economy', 'health'], 55),
#  (['job', 'money'], 56),
#  (['getting', 'back', 'normal'], 57),
#  (['survive'], 58),
#  (['whole', 'scenario', 'impact', 'financial', 'stability'], 59),
#  (['uncertainty'], 60),
#  (['personal', 'family', 'health', 'plus', 'economic', 'environment'], 61),
#  (['nothing'], 62),
#  (['concerned', 'virus', 'affecting', 'worldwide'], 63),
#  (['keeping', 'mentally', 'physically', 'healthy'], 64),
#  (['end'], 65),
#  (['health', 'health', 'friend', 'family'], 66),
#  (['managing',
#    'family',
#    'home',
#    'office',
#    'mention',
#    'home',
#    'maid',
#    'allow',
#    'enter',
#    'society'],
#   67),
#  (['sorry',
#    'lack',
#    'uncertainty',
#    'lack',
#    'certainty',
#    'also',
#    'biggest',
#    'concern'],
#   68),
#  (['uncertainty', 'future'], 69),
#  (['keep', 'safe', 'anaemic', 'self', 'whole', 'mankind'], 70),
#  (['job', 'money'], 71),
#  ([], 72),
#  (['fact', 'beginning', 'community', 'spread', 'could'], 73),
#  (['economic'], 74),
#  (['food'], 75),
#  (['financial', 'loss'], 76),
#  (['direction', 'humanity', 'take'], 77),
#  (['safety', 'family', 'team', 'company'], 78),
#  (['missing', 'office', 'work', 'routine'], 79),
#  (['lack', 'social', 'distending', 'right', 'wing', 'movement'], 80),
#  (['mother'], 81),
#  (['life', 'economy'], 82),
#  (['take', 'advantage', 'staying', 'home', 'coronavirus'], 83),
#  (['suffering', 'job', 'related', 'issue'], 84),
#  (['life',
#    'ever',
#    'normal',
#    'financial',
#    'concern',
#    'fear',
#    'well',
#    'safety',
#    'child'],
#   85),
#  (['adopted',
#    'online',
#    'requirement',
#    'school',
#    'safe',
#    'infected',
#    'could',
#    'thinking',
#    'volunteering',
#    'help',
#    'organization',
#    'also'],
#   86),
#  (['life', 'lockdown'], 87),
#  (['getting', 'bug'], 88),
#  (['health', 'employment'], 89),
#  (['kid', 'education', 'healthy'], 90),
#  (['nothing', 'personal', 'seeing', 'pain', 'lose', 'near', 'one'], 91),
#  (['safety', 'health'], 92),
#  (['security', 'business'], 93),
#  (['self', 'motivation'], 94),
#  (['uncertainty'], 95),
#  (['waiting', 'meet', 'greet', 'child'], 96),
#  (['job', 'security'], 97),
#  (['kid', 'education', 'community', 'business', 'situation'], 98),
#  (['job', 'security', 'quite', 'real'], 99),
#  (['job'], 100),
#  (['worried',
#    'lost',
#    'job',
#    'homeless',
#    'refugee',
#    'poor',
#    'cannot',
#    'protect'],
#   101),
#  (['food', 'biggest', 'concern', 'shortage', 'food'], 102),
#  (['thing', 'slowly', 'start', 'getting', 'back', 'normal'], 103),
#  (['currently', 'strange', 'long', 'way', 'home'], 104),
#  (['health',
#    'loved',
#    'one',
#    'duration',
#    'anaemic',
#    'impact',
#    'economy',
#    'net',
#    'worth'],
#   105),
#  (['fell', 'stuffed', 'spite', 'big', 'house', 'pity', 'living'], 106),
#  (['safety'], 107),
#  (['happens', 'shutdown', 'persist'], 108),
#  (['sustainability'], 109),
#  (['going', 'end', 'soon'], 110),
#  (['future', 'health', 'economic', 'stability'], 111),
#  (['everyone', 'food', 'healthcare'], 112),
#  (['people', 'life'], 113),
#  (['nothing'], 114),
#  (['many', 'deplored'], 115),
#  (['death'], 116),
#  (['health', 'job', 'security', 'impact', 'loved', 'one'], 117),
#  (['environment'], 118),
#  (['fear',
#    'family',
#    'friend',
#    'fear',
#    'death',
#    'dying',
#    'around',
#    'especially',
#    'medium',
#    'report',
#    'sensationalizing',
#    'everything',
#    'happening',
#    'true',
#    'false'],
#   119),
#  (['what', 'going', 'happen', 'may', 'beyond'], 120),
#  (['financial', 'security'], 121),
#  (['relief'], 122),
#  (['health', 'safety'], 123),
#  (['safety', 'heath'], 124),
#  (['end'], 125),
#  (['health', 'job', 'security', 'recession', 'worried', 'family', 'friend'],
#   126),
#  (['future', 'work'], 127),
#  (['survive'], 128),
#  (['family', 'stay', 'well', 'healthy'], 129),
#  (['keeping', 'safe'], 130),
#  (['long', 'last'], 131),
#  (['economy'], 132),
#  (['family', 'safety', 'security', 'financial'], 133),
#  (['maid', 'fully', 'opened'], 134),
#  (['next', 'phase'], 135),
#  (['family', 'safety', 'financial', 'security'], 136),
#  (['food'], 137),
#  (['safety', 'near', 'dear', 'one', 'business', 'challenge'], 138),
#  (['health', 'safety', 'family'], 139),
#  (['inability'], 140),
#  (['corporate', 'revenue', 'impact'], 141),
#  (['slow', 'growth', 'business'], 142),
#  (['health'], 143),
#  (['safe', 'world'], 144),
#  (['economic', 'situation'], 145),
#  (['health', 'family'], 146),
#  (['survive', 'financially', 'catastrophe'], 147),
#  (['business', 'sustainability', 'choosing', 'kid', 'financial', 'pressure'],
#   148),
#  (['society', 'recover'], 149),
#  (['welling'], 150),
#  (['health', 'finance'], 151),
#  (['ensure', 'infected'], 152),
#  (['till', 'continue'], 153),
#  (['enough', 'dying'], 154),
#  (['health', 'well', 'colleague'], 155),
#  (['allah', 'forgive'], 156),
#  (['safety'], 157),
#  (['job', 'future', 'kid'], 158),
#  (['rise', 'could', 'case'], 159),
#  (['worried', 'economy', 'poor'], 160),
#  (['everyone',
#    'follows',
#    'guideline',
#    'effectively',
#    'prevent',
#    'consequence',
#    'spreading'],
#   161),
#  (['health', 'job', 'security'], 162),
#  (['essential'], 163),
#  (['job',
#    'security',
#    'work',
#    'life',
#    'balance',
#    'working',
#    'hour',
#    'increased'],
#   164),
#  (['kid', 'school', 'exam', 'head'], 165),
#  (['parent'], 166),
#  (['job', 'health'], 167),
#  (['staying', 'focused', 'positive', 'motivate', 'healthy'], 168),
#  (['staying', 'healthy'], 169),
#  (['health', 'economic', 'situation'], 170),
#  (['money'], 171),
#  (['end', 'could'], 172),
#  (['cash', 'flow', 'short', 'term', 'future'], 173),
#  (['income', 'concern'], 174),
#  (['end'], 175),
#  (['financial', 'security', 'losing', 'job'], 176),
#  (['economy', 'recession', 'business', 'impacted'], 177),
#  (['watch', 'movie', 'enjoy', 'concern'], 178),
#  (['new', 'learning', 'making'], 179),
#  (['family', 'health', 'safety', 'economic', 'stability'], 180),
#  (['rebuilding', 'life'], 181),
#  (['long', 'last', 'life', 'normal'], 182),
#  (['family', 'safety'], 183),
#  (['mental', 'health'], 184),
#  (['money', 'job', 'health', 'parent', 'also', 'impact', 'poor', 'country'],
#   185),
#  (['hit'], 186),
#  (['job', 'loss', 'find', 'new'], 187),
#  (['prepare', 'tomorrow'], 188),
#  (['food'], 189),
#  (['economy', 'recession', 'business', 'impacted'], 190),
#  (['isolated'], 191),
#  (['economy'], 192),
#  (['cope', 'financially', 'worry', 'family', 'become', 'ill'], 193),
#  (['continent', 'recovery', 'virus'], 194),
#  (['losing', 'job'], 195),
#  (['riot', 'looting', 'around', 'soon'], 196),
#  (['economy'], 197),
#  (['freedom'], 198),
#  (['wont', 'able', 'find', 'cure', 'sickness', 'death'], 199),
#  (['depth',
#    'financial',
#    'impact',
#    'combined',
#    'weak',
#    'leadership',
#    'national',
#    'level'],
#   200),
#  (['safety', 'health'], 201),
#  (['answer', 'question'], 202),
#  ([], 203),
#  (['economic', 'health', 'uncertainty'], 204),
#  (['health', 'issue', 'normalisation', 'life'], 205),
#  (['corporate', 'revenue', 'impact'], 206),
#  (['return', 'normal'], 207),
#  (['health', 'business', 'resumption'], 208),
#  (['economic', 'impact'], 209),
#  (['much'], 210),
#  (['financial'], 211),
#  (['family', 'getting', 'sick', 'economic', 'disaster', 'unfolding'], 212),
#  (['financial', 'security'], 213),
#  (['job', 'security'], 214),
#  (['health', 'loved', 'one'], 215),
#  (['loss', 'loved', 'one'], 216),
#  (['money'], 217),
#  (['health', 'family', 'friend'], 218),
#  (['environment'], 219),
#  (['nothing', 'really', 'work'], 220),
#  (['health', 'crisis', 'end'], 221),
#  (['pakistani',
#    'government',
#    'concerned',
#    'finding',
#    'right',
#    'balance',
#    'ensuring',
#    'stay',
#    'home',
#    'maintaining',
#    'social',
#    'distending',
#    'ensuring',
#    'feeding',
#    'poorest',
#    'poor'],
#   222),
#  (['keeping',
#    'family',
#    'safe',
#    'knowing',
#    'work',
#    'next',
#    'week',
#    'isolation',
#    'fatigue'],
#   223),
#  (['end'], 224),
#  (['job', 'security'], 225),
#  (['restricted', 'movement', 'raging', 'parent', 'job', 'security'], 226),
#  (['missing', 'opportunity'], 227),
#  (['health'], 228),
#  (['fact', 'beginning', 'community', 'spread', 'could'], 229),
#  (['economy'], 230),
#  (['finance', 'work', 'life', 'balance', 'health', 'loved', 'one'], 231),
#  (['safety', 'family', 'job', 'security'], 232),
#  (['money'], 233),
#  (['stay', 'positive'], 234),
#  (['health', 'family', 'job'], 235),
#  (['uncertainty'], 236),
#  (['school', 'open'], 237),
#  (['lack',
#    'understanding',
#    'everyone',
#    'including',
#    'medical',
#    'profession',
#    'government'],
#   238),
#  (['concern',
#    'health',
#    'family',
#    'besides',
#    'economic',
#    'situation',
#    'country',
#    'due',
#    'lock',
#    'affecting',
#    'low',
#    'income',
#    'group'],
#   239),
#  (['physically',
#    'challenged',
#    'going',
#    'get',
#    'daily',
#    'requirement',
#    'online',
#    'delivery',
#    'use',
#    'depend'],
#   240),
#  (['money'], 241),
#  (['wondering', 'long', 'last'], 242),
#  (['going', 'run', 'food'], 243),
#  (['recession'], 244),
#  (['waste', 'life'], 245),
#  (['job', 'security'], 246),
#  (['concern'], 247),
#  (['world', 'heal', 'ever'], 248),
#  (['tell', 'passed'], 249),
#  (['happens'], 250),
#  (['able', 'see', 'loved', 'one', 'abroad'], 251),
#  (['uncertainty', 'loss', 'freedom'], 252),
#  (['going', 'end', 'soon'], 253),
#  (['health'], 254),
#  (['well', 'business', 'think', 'get', 'back', 'normal', 'soon'], 255),
#  (['quarante'], 256),
#  (['nothing', 'much'], 257),
#  (['becoming', 'fat'], 258),
#  (['infection', 'financial'], 259),
#  (['want',
#    'also',
#    'say',
#    'see',
#    'lot',
#    'room',
#    'use',
#    'current',
#    'situation',
#    'drive',
#    'positive',
#    'change'],
#   260),
#  (['child', 'using', 'much', 'technology', 'physically', 'active'], 261),
#  (['someone',
#    'care',
#    'die',
#    'virus',
#    'economy',
#    'fragile',
#    'state',
#    'many',
#    'taking',
#    'virus',
#    'seriously',
#    'enough'],
#   262),
#  (['pp'], 263),
#  (['job', 'security'], 264),
#  (['business', 'growth', 'family', 'visit', 'kid', 'pastime', 'friend'], 265),
#  (['could', 'recovery'], 266),
#  (['money'], 267),
#  (['risk',
#    'elderly',
#    'loved',
#    'one',
#    'face',
#    'friend',
#    'family',
#    'whose',
#    'life',
#    'opened'],
#   268),
#  (['money', 'end', 'goal', 'pitted', 'eachother', 'dishonest', 'motif'], 269),
#  (['job', 'security'], 270),
#  (['market', 'resume'], 271),
#  (['job', 'security'], 272),
#  (['job', 'health'], 273),
#  (['financial', 'concern', 'health', 'concern'], 274),
#  (['everywhere', 'top', 'aspect', 'life'], 275),
#  (['breaking', 'chain', 'spread', 'corona', 'virus'], 276),
#  (['going', 'end', 'soon'], 277),
#  (['die', 'without', 'achevieng', 'goal'], 278),
#  ([], 279),
#  (['uncertainty'], 280),
#  (['job', 'security', 'finance'], 281),
#  (['world',
#    'never',
#    'economic',
#    'growth',
#    'worst',
#    'affected',
#    'situation',
#    'offer',
#    'opportunity',
#    'bring',
#    'good',
#    'positive',
#    'change'],
#   282),
#  (['want', 'world', 'beautiful', 'filled', 'kind', 'human'], 283),
#  (['regarding', 'economic', 'recession'], 284),
#  (['work'], 285),
#  (['family', 'health', 'uncertainty', 'future'], 286),
#  (['biggest', 'concern', 'got', 'back', 'work'], 287),
#  (['deadline'], 288),
#  (['whether', 'get', 'better'], 289),
#  (['quarante'], 290),
#  (['financial', 'well'], 291),
#  (['idea', 'long', 'go'], 292),
#  (['workwise', 'hard', 'manage', 'plus', 'fear', 'unknown'], 293),
#  (['interaction'], 294),
#  (['working',
#    'fee',
#    'lance',
#    'research',
#    'writer',
#    'organisation',
#    'company',
#    'avoiding',
#    'make',
#    'payment'],
#   295),
#  (['global', 'health', 'economic', 'condition'], 296),
#  (['small', 'business', 'poor'], 297),
#  (['health', 'family', 'member'], 298),
#  (['economy'], 299),
#  (['business'], 300),
#  (['returning', 'work', 'getting', 'income', 'take', 'care', 'family'], 301)]

# %%
# Build a TF-IDF matrix before run the LDA
df_txts = sqlContext.createDataFrame(token, ["List_of_words", 'Index'])

#TF
cv = CountVectorizer (inputCol = "List_of_words",
                     outputCol = "raw_features", vocabSize = 5000, minDF = 10.0)

cvmodel = cv.fit(df_txts)

result_cv = cvmodel.transform(df_txts)

# IDF
idf = IDF (inputCol = 'raw_features', outputCol = 'features')
idfModel = idf.fit(result_cv)
result_tfidf = idfModel.transform(result_cv)

# %%
result_cv.show()
# Out:
# +--------------------+-----+--------------------+
# |       List_of_words|Index|        raw_features|
# +--------------------+-----+--------------------+
# |[economic, impact...|    0|      (14,[7],[1.0])|
# |   [elderly, family]|    1|      (14,[2],[1.0])|
# |[essential, servi...|    2|          (14,[],[])|
# |[safety, well, fa...|    3|(14,[2,5],[1.0,1.0])|
# |      [free, corona]|    4|          (14,[],[])|
# |[health, financia...|    5|(14,[0,3,4],[1.0,...|
# |[finance, economy...|    6|      (14,[6],[1.0])|
# |          [choosing]|    7|          (14,[],[])|
# |[much, delivering...|    8|     (14,[10],[1.0])|
# |             [money]|    9|     (14,[13],[1.0])|
# |[long, last, life...|   10|      (14,[9],[1.0])|
# |[suffering, virus...|   11|      (14,[7],[1.0])|
# |        [world, run]|   12|          (14,[],[])|
# |[work, place, cur...|   13|     (14,[10],[1.0])|
# |[job, security, m...|   14|(14,[1,3],[1.0,1.0])|
# |        [everything]|   15|          (14,[],[])|
# |     [achieve, want]|   16|          (14,[],[])|
# |[job, guarantee, ...|   17|      (14,[1],[1.0])|
# |[financial, well,...|   18|(14,[4,5],[1.0,1.0])|
# |       [losing, job]|   19|      (14,[1],[1.0])|
# +--------------------+-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# Explaination of the above terms:
#
# "minDF" is used for removing terms that appear too infrequently.
#
# For example: minDF = 0.01 means "ignore terms that appear in less than 1% of the documents". minDF = 5 means "ignore terms that appear in less than 5 documents".
#
# The default minDF is 1, which means "ignore terms that appear in less than 1 document". Thus, the default setting does not ignore any terms.
#
# "vocabSize" is the maximum number of tokens you can have in your vocabulary. The default is 1 << 18. I.e., 2^18 or 262,144.

# %%
df_txts.collect()
result_tfidf.show()
# Out:
# +--------------------+-----+--------------------+--------------------+
# |       List_of_words|Index|        raw_features|            features|
# +--------------------+-----+--------------------+--------------------+
# |[economic, impact...|    0|      (14,[7],[1.0])|(14,[7],[2.941144...|
# |   [elderly, family]|    1|      (14,[2],[1.0])|(14,[2],[2.346436...|
# |[essential, servi...|    2|          (14,[],[])|          (14,[],[])|
# |[safety, well, fa...|    3|(14,[2,5],[1.0,1.0])|(14,[2,5],[2.3464...|
# |      [free, corona]|    4|          (14,[],[])|          (14,[],[])|
# |[health, financia...|    5|(14,[0,3,4],[1.0,...|(14,[0,3,4],[1.97...|
# |[finance, economy...|    6|      (14,[6],[1.0])|(14,[6],[2.880519...|
# |          [choosing]|    7|          (14,[],[])|          (14,[],[])|
# |[much, delivering...|    8|     (14,[10],[1.0])|(14,[10],[3.14878...|
# |             [money]|    9|     (14,[13],[1.0])|(14,[13],[3.31583...|
# |[long, last, life...|   10|      (14,[9],[1.0])|(14,[9],[3.074675...|
# |[suffering, virus...|   11|      (14,[7],[1.0])|(14,[7],[2.941144...|
# |        [world, run]|   12|          (14,[],[])|          (14,[],[])|
# |[work, place, cur...|   13|     (14,[10],[1.0])|(14,[10],[3.14878...|
# |[job, security, m...|   14|(14,[1,3],[1.0,1.0])|(14,[1,3],[2.0501...|
# |        [everything]|   15|          (14,[],[])|          (14,[],[])|
# |     [achieve, want]|   16|          (14,[],[])|          (14,[],[])|
# |[job, guarantee, ...|   17|      (14,[1],[1.0])|(14,[1],[2.050171...|
# |[financial, well,...|   18|(14,[4,5],[1.0,1.0])|(14,[4,5],[2.7692...|
# |       [losing, job]|   19|      (14,[1],[1.0])|(14,[1],[2.050171...|
# +--------------------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
# Run the LDA model:
from pyspark.ml.clustering import LDA

num_topics = 5
max_iterations = 1000

lda = LDA(k = num_topics, maxIter = max_iterations)
lda_model = lda.fit(result_tfidf)

# %%
# Describe
topics = lda_model.describeTopics()
topics.show()
# Out:
# +-----+--------------------+--------------------+
# |topic|         termIndices|         termWeights|
# +-----+--------------------+--------------------+
# |    0|[11, 13, 0, 1, 3,...|[0.91573486093191...|
# |    1|[6, 8, 9, 0, 4, 5...|[0.52151169406768...|
# |    2|[2, 0, 9, 10, 5, ...|[0.33335682399974...|
# |    3|[5, 7, 12, 0, 2, ...|[0.32524406210308...|
# |    4|[1, 3, 4, 13, 0, ...|[0.36592794664356...|
# +-----+--------------------+--------------------+

# %%
vocabList = cvmodel.vocabulary
termindices_need = topics.select('termIndices').collect()
termWeights_need = topics.select('termWeights').collect()



def topic_render (topic):
    res = []
    for i in range(len(topic)):
        ele = []
        for j in range (10):
            term = vocabList[topic[i][0][j]]
            ele.append (term)
        res.append(ele)
    return res

topic_words = topic_render(termindices_need)

for topic in range(len(topic_words)):
    print ("Topic" + str(topic) + ":")
    weights=termWeights_need[topic][0]
    topic_word=topic_words[topic]
    for i in range(len(weights)):
        print (topic_word[i],':',weights[i])
    print ('\n')
# Out:
# Topic0:
# end : 0.9157348609319139
# money : 0.006574164240931151
# health : 0.0065239328166525265
# job : 0.006469731091971622
# security : 0.006469731091957425
# financial : 0.006469731091933683
# economy : 0.006469731091925575
# work : 0.006469731091874557
# uncertainty : 0.006469731091841036
# economic : 0.006469731091832255
#
#
# Topic1:
# economy : 0.5215116940676887
# business : 0.4506881391266776
# life : 0.0023284932525762573
# health : 0.002326134469299257
# financial : 0.0023223104617566405
# safety : 0.002318894588898102
# security : 0.0023186958750037903
# family : 0.002315730356544572
# money : 0.002311651300283012
# economic : 0.0023116513002670097
#
#
# Topic2:
# family : 0.33335682399974675
# health : 0.31605427099521716
# life : 0.18591949546845293
# work : 0.1544390488889868
# safety : 0.001028794662578692
# job : 0.0010268932789696537
# security : 0.0010243487246737865
# economic : 0.0010236673140313062
# financial : 0.0010231072824209864
# uncertainty : 0.0010216047320246223
#
#
# Topic3:
# safety : 0.32524406210308515
# economic : 0.29679916645510235
# uncertainty : 0.239343890239904
# health : 0.12523911615949793
# family : 0.0013609531553845202
# financial : 0.0013386221487353567
# security : 0.0013370033074677492
# job : 0.0013348449351069595
# business : 0.0013348195448764533
# life : 0.0013343668455579971
#
#
# Topic4:
# job : 0.36592794664356443
# security : 0.296186509881719
# financial : 0.18955425459637515
# money : 0.13907564161614555
# health : 0.0009331169646401501
# family : 0.0009303260863335637
# safety : 0.0009299347547314294
# business : 0.0009239396994909054
# life : 0.0009238808614289133
# work : 0.0009233425897334541

# %%
import pandas as pd
df=pd.read_csv("LDA Visualization.csv")
df
# Out:
#                              Topic0:       word    weight
# 0           end : 0.9157348609319139       end   0.915735
# 1       money : 0.006574164240931151     money   0.006574
# 2     health : 0.0065239328166525265    health   0.006524
# 3         job : 0.006469731091971622       job   0.006470
# 4    security : 0.006469731091957425  security   0.006470
# ..                               ...        ...       ...
# 57    family : 0.0009303260863335637    family   0.000930
# 58    safety : 0.0009299347547314294    safety   0.000930
# 59  business : 0.0009239396994909054  business   0.000924
# 60      life : 0.0009238808614289133      life   0.000924
# 61      work : 0.0009233425897334541      work   0.000923
#
# [62 rows x 3 columns]

# %%
fig, axes = plt.subplots(nrows =3, ncols = 2, figsize = (16,8))
#df = [pd_curr_word_freq, pd_future_word_freq,pd_now_word_freq]

plt.subplot(3,2,1)
sns.barplot(y="weight", x="word",data=df.loc[:10,["word","weight"]])
sns.set(rc = {'figure.figsize': (8,6)})
plt.title("COVID-19 End")
display()

plt.subplot(3,2,2)
sns.barplot(y="weight", x="word",data=df.loc[13:23,["word","weight"]])
sns.set(rc = {'figure.figsize': (8,6)})
plt.title("Economy and Business")
display()

plt.subplot(3,2,3)
sns.barplot(y="weight", x="word",data=df.loc[26:36,["word","weight"]])
sns.set(rc = {'figure.figsize': (8,6)})
plt.title("Family and Health")
display()

plt.subplot(3,2,4)
sns.barplot(y="weight", x="word",data=df.loc[39:49,["word","weight"]])
sns.set(rc = {'figure.figsize': (8,6)})
plt.title("Safety")
display()

plt.subplot(3,2,5)
sns.barplot(y="weight", x="word",data=df.loc[52:62,["word","weight"]])
sns.set(rc = {'figure.figsize': (8,6)})
plt.title("Job")
display()

plt.tight_layout()

# %% [markdown]
# ### Unemployed Rate and CVI (COVID-19 Vulnerable Index)
#
# The COVID-19 Vulnerability Index (CVI) is a measurement of the negative impact that the coronavirus (COVID-19) crisis can have on employment based upon a region's mix of industries. For example, accommodation and food services are projected to lose more jobs as a result of the coronavirus (in the neighborhood of 50%) compared with utilities and healthcare (with none or little expected job contraction).
#
# An average Vulnerability Index score is 100, representing the average job loss expected in the United States. Higher scores indicate the degree to which job losses may be greater — an index score of 200, for example, means the rate of job loss can be twice as large as the national average. Conversely, an index score of 50 would mean a possible job loss of half the national average. Regions heavily dependent on tourism with relatively high concentrations of leisure and hospitality jobs, for example, are likely to have high index scores.
#
# The Vulnerability Index only measures the impact potential related to the mix of industry employment. The index does not take into account variation due to a region’s rate of virus infection, nor does it factor in local government's policies in reaction to the virus.

# %%
unemp = pd.read_csv("Downloads/Bureau_of_Labor_Statistics_Monthly_Unemployment__current_14_months_.csv")
cvi = pd.read_csv("Downloads/Chmura_CVI_Counties_April_2020.csv")

# %%
# Check Point:
print (unemp.duplicated().sum())
print (unemp.isna().sum())
# Out:
# 0
# FID                            0
# COUNTYNS                       0
# GEOID                          0
# ALAND                          0
# AWATER                         0
# NAME                           0
# State                          0
# fips                           0
# LaborForce_CurrentMonth       78
# LaborForce_01Month            78
# LaborForce_02Month             0
# LaborForce_03Month             0
# LaborForce_04Month             0
# LaborForce_05Month             0
# LaborForce_06Month             0
# LaborForce_07Month             0
# LaborForce_08Month             0
# LaborForce_09Month             0
# LaborForce_10Month             0
# LaborForce_11Month             0
# LaborForce_12Month             0
# LaborForce_13Month             0
# Employed_CurrentMonth         78
# Employed_01Month              78
# Employed_02Month               0
# Employed_03Month               0
# Employed_04Month               0
# Employed_05Month               0
# Employed_06Month               0
# Employed_07Month               0
#                               ..
# PctUnemployed_CurrentMonth    78
# PctUnemployed_01Month         78
# PctUnemployed_02Month          0
# PctUnemployed_03Month          0
# PctUnemployed_04Month          0
# PctUnemployed_05Month          0
# PctUnemployed_06Month          0
# PctUnemployed_07Month          0
# PctUnemployed_08Month          0
# PctUnemployed_09Month          0
# PctUnemployed_10Month          0
# PctUnemployed_11Month          0
# PctUnemployed_12Month          0
# PctUnemployed_13Month          0
# CurrentMonth                   0
# P01Month                       0
# P02Month                       0
# P03Month                       0
# P04Month                       0
# P05Month                       0
# P06Month                       0
# P07Month                       0
# P08Month                       0
# P09Month                       0
# P10Month                       0
# P11Month                       0
# P12Month                       0
# P13Month                       0
# SHAPE_Length                   0
# SHAPE_Area                     0
# Length: 80, dtype: int64

# %%
### Get the Columns indices
i = 0
for column in unemp.columns:
    print ('%d'%i + " " + column + '\n')
    i += 1
# Out:
# 0 FID
#
# 1 COUNTYNS
#
# 2 GEOID
#
# 3 ALAND
#
# 4 AWATER
#
# 5 NAME
#
# 6 State
#
# 7 fips
#
# 8 LaborForce_CurrentMonth
#
# 9 LaborForce_01Month
#
# 10 LaborForce_02Month
#
# 11 LaborForce_03Month
#
# 12 LaborForce_04Month
#
# 13 LaborForce_05Month
#
# 14 LaborForce_06Month
#
# 15 LaborForce_07Month
#
# 16 LaborForce_08Month
#
# 17 LaborForce_09Month
#
# 18 LaborForce_10Month
#
# 19 LaborForce_11Month
#
# 20 LaborForce_12Month
#
# 21 LaborForce_13Month
#
# 22 Employed_CurrentMonth
#
# 23 Employed_01Month
#
# 24 Employed_02Month
#
# 25 Employed_03Month
#
# 26 Employed_04Month
#
# 27 Employed_05Month
#
# 28 Employed_06Month
#
# 29 Employed_07Month
#
# 30 Employed_08Month
#
# 31 Employed_09Month
#
# 32 Employed_10Month
#
# 33 Employed_11Month
#
# 34 Employed_12Month
#
# 35 Employed_13Month
#
# 36 Unemployed_CurrentMonth
#
# 37 Unemployed_01Month
#
# 38 Unemployed_02Month
#
# 39 Unemployed_03Month
#
# 40 Unemployed_04Month
#
# 41 Unemployed_05Month
#
# 42 Unemployed_06Month
#
# 43 Unemployed_07Month
#
# 44 Unemployed_08Month
#
# 45 Unemployed_09Month
#
# 46 Unemployed_10Month
#
# 47 Unemployed_11Month
#
# 48 Unemployed_12Month
#
# 49 Unemployed_13Month
#
# 50 PctUnemployed_CurrentMonth
#
# 51 PctUnemployed_01Month
#
# 52 PctUnemployed_02Month
#
# 53 PctUnemployed_03Month
#
# 54 PctUnemployed_04Month
#
# 55 PctUnemployed_05Month
#
# 56 PctUnemployed_06Month
#
# 57 PctUnemployed_07Month
#
# 58 PctUnemployed_08Month
#
# 59 PctUnemployed_09Month
#
# 60 PctUnemployed_10Month
#
# 61 PctUnemployed_11Month
#
# 62 PctUnemployed_12Month
#
# 63 PctUnemployed_13Month
#
# 64 CurrentMonth
#
# 65 P01Month
#
# 66 P02Month
#
# 67 P03Month
#
# 68 P04Month
#
# 69 P05Month
#
# 70 P06Month
#
# 71 P07Month
#
# 72 P08Month
#
# 73 P09Month
#
# 74 P10Month
#
# 75 P11Month
#
# 76 P12Month
#
# 77 P13Month
#
# 78 SHAPE_Length
#
# 79 SHAPE_Area

# %%
unemp_df = unemp.iloc[:,[5,6,7,8,9,22,23,36,37,50,51,64,65]]
unemp_df.head()
# Out:
#              NAME    State  fips  LaborForce_CurrentMonth  LaborForce_01Month  \
# 0  Autauga County  Alabama  1001                  25215.0             25835.0
# 1  Baldwin County  Alabama  1003                  91688.0             96391.0
# 2  Barbour County  Alabama  1005                   8101.0              8537.0
# 3     Bibb County  Alabama  1007                   9041.0              8617.0
# 4   Blount County  Alabama  1009                  23980.0             25103.0
#
#    Employed_CurrentMonth  Employed_01Month  Unemployed_CurrentMonth  \
# 0                22321.0           25114.0                   2894.0
# 1                77301.0           93782.0                  14387.0
# 2                 7292.0            8221.0                    809.0
# 3                 7437.0            8348.0                   1604.0
# 4                21711.0           24421.0                   2269.0
#
#    Unemployed_01Month  PctUnemployed_CurrentMonth  PctUnemployed_01Month  \
# 0               721.0                        11.5                    2.8
# 1              2609.0                        15.7                    2.7
# 2               316.0                        10.0                    3.7
# 3               269.0                        17.7                    3.1
# 4               682.0                         9.5                    2.7
#
#                CurrentMonth    P01Month
# 0  April 2020 - Preliminary  March 2020
# 1  April 2020 - Preliminary  March 2020
# 2  April 2020 - Preliminary  March 2020
# 3  April 2020 - Preliminary  March 2020
# 4  April 2020 - Preliminary  March 2020

# %%
cvi_col_name = ['County_Name', 'State', 'CVI', 'Rank','ObjectId','Excel_ID', 'FIPS']
cvi.columns = cvi_col_name

cvi_df = cvi.drop(['ObjectId','Excel_ID'], axis=1)

# %%
## Check point
cvi_df.isna().sum()
cvi_df.duplicated().sum()
cvi_df.head(5)
# Out:
#         County_Name    State     CVI  Rank  FIPS
# 0        Lee County  Alabama  119.27   263  1081
# 1  Limestone County  Alabama   86.90  1504  1083
# 2    Lowndes County  Alabama   62.09  2672  1085
# 3      Macon County  Alabama   77.36  2029  1087
# 4    Madison County  Alabama   92.55  1191  1089

# %%
# Join two dfs
unemp_cvi = pd.merge(unemp_df, cvi_df, left_on = ['NAME','State'], right_on = ['County_Name', 'State'])\
        .drop('County_Name', axis = 1)

unemp_cvi.head(5)

unemp_cvi['CurrentMonth'] = unemp_cvi['CurrentMonth'].map(lambda x: x.rstrip(' - Preliminary'))

# %% [markdown]
# ### Incorporated with National Unemployment Insurance Weekly Claims Data
# Data source: Unemployment Insurance Weekly Claims Data - 2020 year to date, retrieve from here:
# https://oui.doleta.gov/unemploy/DataDashboard.asp

# %%
unemp_ins = pd.read_csv('unemp_ins.csv')

# %%
unemp_ins['Reflact_Week'] = pd.to_datetime(unemp_ins['Reflact_Week'])

# %%
fig, ax = plt.subplots(figsize=(16, 6))
a=sns.lineplot(data=unemp_ins, x='Reflact_Week', y='Total_Claims')
